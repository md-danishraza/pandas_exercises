# %% [markdown]
# # Tips

# %% [markdown]
# ### Introduction:
#
# This exercise was created based on the tutorial and documentation from [Seaborn](https://stanford.edu/~mwaskom/software/seaborn/index.html)
# The dataset being used is tips from Seaborn.
#
# ### Step 1. Import the necessary libraries:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Tips/tips.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called tips

# %%
tips = pd.read_csv("tips.csv")
tips.head()
# Out:
#    Unnamed: 0  total_bill   tip     sex smoker  day    time  size
# 0           0       16.99  1.01  Female     No  Sun  Dinner     2
# 1           1       10.34  1.66    Male     No  Sun  Dinner     3
# 2           2       21.01  3.50    Male     No  Sun  Dinner     3
# 3           3       23.68  3.31    Male     No  Sun  Dinner     2
# 4           4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Step 4. Delete the Unnamed 0 column

# %%
tips = tips.drop('Unnamed: 0', axis=1)

# %%
tips = tips.iloc[:,1:]
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Step 5. Plot the total_bill column histogram

# %%
tips.total_bill.min()
# Out:
# 3.07

# %%
plt.hist(tips['total_bill'], bins=10, edgecolor='black')
plt.xlabel('Total Bill')
plt.ylabel('Frequency')
plt.title('Histogram of Total Bill')
# Out:
# Text(0.5, 1.0, 'Histogram of Total Bill')

# %% [markdown]
# ### Step 6. Create a scatter plot presenting the relationship between total_bill and tip

# %%
tips
# Out:
#      total_bill   tip  sex smoker   day    time  size
# 0         16.99  1.01  NaN     No   Sun  Dinner     2
# 1         10.34  1.66  NaN     No   Sun  Dinner     3
# 2         21.01  3.50  NaN     No   Sun  Dinner     3
# 3         23.68  3.31  NaN     No   Sun  Dinner     2
# 4         24.59  3.61  NaN     No   Sun  Dinner     4
# ..          ...   ...  ...    ...   ...     ...   ...
# 239       29.03  5.92  NaN     No   Sat  Dinner     3
# 240       27.18  2.00  NaN    Yes   Sat  Dinner     2
# 241       22.67  2.00  NaN    Yes   Sat  Dinner     2
# 242       17.82  1.75  NaN     No   Sat  Dinner     2
# 243       18.78  3.00  NaN     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips['sex'] = tips['sex'].map({'Male': 0, 'Female': 1})

# %%
plt.scatter(tips['total_bill'], tips['tip'], edgecolor='black',c=tips['sex'],cmap="coolwarm")

plt.xlabel('Total Bill')
plt.ylabel('Tip')
# plt.legend(true)
plt.title('Relationship b/w Total Bill & Tip')

plt.show()

# %%
sns.scatterplot(x='total_bill', y='tip', data=tips,hue='sex')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ### Step 7.  Create one image with the relationship of total_bill, tip and size.
# #### Hint: It is just one function.

# %%
sns.pairplot(tips)

# %%
from mpl_toolkits.mplot3d import Axes3D

# Create a 3D scatter plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(tips['total_bill'], tips['tip'], tips['size'], edgecolor='black')

ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
ax.set_zlabel('Size')
ax.set_title('Relationship b/w Total Bill, Tip, and Size')

plt.show()

# %% [markdown]
# ### Step 8. Present the relationship between days and total_bill value

# %%
sns.set_theme(style="darkgrid")
sns.stripplot(x="day", y="total_bill", data=tips,jitter=True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### Step 9. Create a scatter plot with the day as the y-axis and tip as the x-axis, differ the dots by sex

# %%
sns.stripplot(x="tip", y="day", hue="sex", data=tips)
# Out:
# <Axes: xlabel='tip', ylabel='day'>

# %% [markdown]
# ### Step 10.  Create a box plot presenting the total_bill per day differetiation the time (Dinner or Lunch)

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x="day", y="total_bill", hue="time", data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### Step 11. Create two histograms of the tip value based for Dinner and Lunch. They must be side by side.

# %%
sns.histplot(data=tips, x="tip", hue="time",bins=10, kde=True, multiple="dodge")
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %% [markdown]
# ### Step 12. Create two scatterplots graphs, one for Male and another for Female, presenting the total_bill value and tip relationship, differing by smoker or no smoker
# ### They must be side by side.

# %%
male = tips[tips['sex'] == 1]
female = tips[tips['sex'] == 0]

sns.scatterplot(x='total_bill', y='tip', data=male, hue='smoker')
plt.title('Male - Total Bill vs Tip (Smoker vs Non-Smoker)')

sns.scatterplot(x='total_bill', y='tip', data=female,hue='smoker')
plt.title('Female - Total Bill vs Tip (Smoker vs Non-Smoker)')
# Out:
# Text(0.5, 1.0, 'Female - Total Bill vs Tip (Smoker vs Non-Smoker)')

# %%
male
# Out:
# Empty DataFrame
# Columns: [total_bill, tip, sex, smoker, day, time, size]
# Index: []

# %% [markdown]
# ### BONUS: Create your own question and answer it using a graph.
